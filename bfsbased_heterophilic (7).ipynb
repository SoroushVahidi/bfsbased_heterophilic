# %%
# !pip install gurobipy
# !pip install torch_geometric
#!pip install torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric


import numpy as np
import gurobipy as gp
from gurobipy import GRB
import torch
from sklearn.model_selection import train_test_split

import itertools
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.metrics import pairwise_distances as sklearn_pairwise_distances
import networkx as nx
 # Use "cosine" for cosine similarity
import heapq


os.environ["GRB_LICENSE_FILE"] = "gurobi (3).lic"
os.environ["GRB_WLSACCESSID"] = "f218200d-1f8d-4342-83f5-b7b2d9263751"  # Replace with your actual WLSACCESSID
os.environ["GRB_WLSSECRET"] = "528d596b-babc-4a1e-bda2-693c44f4f006"  # Replace with your actual WLSSECRET
os.environ["GRB_LICENSEID"] = "840285"  # Replace with your actual LICENSEID

from collections import Counter
from sklearn.metrics.pairwise import cosine_distances
from torch_geometric.datasets import WebKB, WikipediaNetwork, Actor

from torch_geometric.datasets import FacebookPagePage

from torch_geometric.datasets import SNAPDataset

import numpy as np
import torch
import random
import networkx as nx
from torch_geometric.datasets import WebKB
from collections import Counter, defaultdict
from sklearn.metrics import accuracy_score
from sortedcontainers import SortedSet  # Ordered set
from torch_geometric.utils import to_networkx

from torch_geometric.datasets import WikipediaNetwork
# Out:
# Requirement already satisfied: gurobipy in /usr/local/lib/python3.11/dist-packages (12.0.1)
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.11/dist-packages (2.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.13)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2024.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.1.31)

# %%
#dataset = WebKB(root='data', name='Cornell')
#dataset = WebKB(root='data', name='texas')
#dataset = WikipediaNetwork(root='data', name='chameleon')
#dataset = WikipediaNetwork(root='data', name='squirrel')
dataset = WebKB(root='data', name='Wisconsin')
data = dataset[0]
data.edge_index = torch.cat([data.edge_index, data.edge_index.flip(0)], dim=1)

# ✅ Remove duplicate edges
data.edge_index = torch.unique(data.edge_index, dim=1)

# ✅ Convert to NetworkX Graph to Find Components
G = to_networkx(data, to_undirected=True)
components = list(nx.connected_components(G))
num_components = len(components)

print(f"\n✅ Loaded  dataset with {data.num_nodes} nodes, {data.edge_index.shape[1]} edges")
print(f"   - Features: {data.x.shape[1]}")
print(f"   - Number of Classes: {len(set(data.y.numpy()))}")
print(f"   - Number of Components: {num_components}")

# ✅ Set Training Percentage
train_percentage = 0.65

# ✅ Select Training Nodes
train_indices = []
for component in components:
    component = list(component)
    t = max(1, int(train_percentage * len(component)))
    sampled_nodes = np.random.choice(component, t, replace=False)
    train_indices.extend(sampled_nodes)

np.random.shuffle(train_indices)

# ✅ Initialize Prediction Labels
y_pred = np.full(data.num_nodes, -1)
for idx in train_indices:
    y_pred[idx] = data.y[idx].item()

# ✅ Compute Label Distribution
total_label_counts = Counter(data.y.numpy())
num_labels = len(set(data.y.numpy()))
alpha = 1  # Laplace smoothing

dataset_label_distribution = {
    lbl: (total_label_counts[lbl] + alpha) / (len(data.y) + alpha * num_labels)
    for lbl in total_label_counts.keys()
}

train_label_counts = Counter(y_pred[train_indices])

train_label_distribution = {
    lbl: (train_label_counts.get(lbl, 0) + alpha) / (len(train_indices) + alpha * num_labels)
    for lbl in dataset_label_distribution.keys()
}

# ✅ Precompute Neighbors for Each Node
A = torch.zeros((data.num_nodes, data.num_nodes))
A[data.edge_index[0], data.edge_index[1]] = 1
A = A.numpy()
neighbors_dict = {i: set(np.where(A[i] == 1)[0]) for i in range(data.num_nodes)}

# ✅ Track Instances Assigned to Each Label
class_instances = defaultdict(set)
for idx in train_indices:
    class_instances[data.y[idx].item()].add(idx)

# ✅ Ordered Set for Managing Unlabeled Vertices
ordered_set = SortedSet()
train_labeled_nodes = set(train_indices)

for node in range(data.num_nodes):
    if y_pred[node] == -1:  # Only process unlabeled nodes
        labeled_neighbors = [n for n in neighbors_dict[node] if y_pred[n] != -1]
        num_labeled_by_train = sum(1 for n in labeled_neighbors if n in train_labeled_nodes)
        num_labeled_by_propagation = len(labeled_neighbors) - num_labeled_by_train
        total_neighbors = len(neighbors_dict[node])

        if total_neighbors > 0:
            weighted_score = (num_labeled_by_propagation + 3 * num_labeled_by_train) / total_neighbors
        else:
            weighted_score = 0

        ordered_set.add((-weighted_score, node))

# ✅ Iteratively Label the Most Constrained Nodes
while ordered_set:
    _, node = ordered_set.pop(0)

    if y_pred[node] != -1:
        continue

    # Get labeled neighbors
    neighbor_labels = [y_pred[n] for n in neighbors_dict[node] if y_pred[n] != -1]
    label_counts = Counter(neighbor_labels)

    # 🚨 If this node has 0 labeled neighbors
    if not neighbor_labels:
        print(f"\n🚨 STRANGE: Node {node} was chosen, but it has 0 labeled neighbors!")
        break

    # Compute Neighbor Label Distribution
    neighbor_label_counts = Counter(neighbor_labels)
    total_labeled_neighbors = len(neighbor_labels)

    if total_labeled_neighbors > 0:
        neighbor_label_distribution = {
            lbl: neighbor_label_counts[lbl] / total_labeled_neighbors for lbl in neighbor_label_counts.keys()
        }
    else:
        neighbor_label_distribution = {lbl: 0 for lbl in dataset_label_distribution.keys()}

    # ✅ Compute Feature Distance to Each Class
    # feature_diffs = {}
    # for lbl in dataset_label_distribution.keys():
    #   if class_instances[lbl]:  # Only compute if we have instances of the label
    #       instance_features = data.x[list(class_instances[lbl])]
    #       node_feature = data.x[node].unsqueeze(0)

    #       # Compute distances for each instance
    #       distances = torch.norm(instance_features - node_feature, dim=1).tolist()

    #       # Apply weight based on whether the instance is from training or predicted labels
    #       weighted_distances = [
    #           (3 * dist) if instance in train_indices else dist  # Give 3x weight if in training set
    #           for instance, dist in zip(class_instances[lbl], distances)
    #       ]

    #       # Compute weighted average distance
    #       avg_distance = sum(weighted_distances) / len(weighted_distances)
    #       feature_diffs[lbl] = avg_distance
    #   else:
    #       feature_diffs[lbl] = 0  # No penalty if no instances exist

    feature_diffs = {}
    for lbl in dataset_label_distribution.keys():
        if class_instances[lbl]:  # Only compute if we have instances of the label
            instance_features = data.x[list(class_instances[lbl])]
            node_feature = data.x[node].unsqueeze(0)
            print(len(instance_features),len(node_feature))
            avg_distance = torch.mean(torch.norm(instance_features - node_feature, dim=1)).item()
            feature_diffs[lbl] = avg_distance
        else:
            feature_diffs[lbl] = 0  # No penalty if no instances exist

    # ✅ Select the Best Label Based on the Adjusted Score
    best_label_candidates = []
    max_value = float('-inf')
    a1=0.5
    a2=-6
    a3=-2
    a4=1
    a5=3
    for lbl in dataset_label_distribution.keys():
        score = (
            a1*train_label_distribution.get(lbl, 0)
            +a2* neighbor_label_distribution.get(lbl, 0)
            +a3*feature_diffs[lbl]  # Penalize by average feature distance
        )
        print(lbl,score,)

        if score - max_value > 0.01:
            best_label_candidates = [lbl]
            max_value = score
        elif abs(score - max_value) <= 0.01:
            best_label_candidates.append(lbl)


    best_label = random.choice(best_label_candidates)
    y_pred[node] = best_label
    class_instances[best_label].add(node)  # Track newly labeled nodes
    neighbor_labels = [y_pred[n] for n in neighbors_dict[node] if y_pred[n] != -1]
    label_counts = Counter(neighbor_labels)

    print(f"\n🔹 Labelling Node {node} ")
    # ✅ Print Prediction Outcome
    true_label = data.y[node].item()
    correct = "✅" if best_label == true_label else "❌"
    print(f"   -> Predicted Label: {best_label} | True Label: {true_label} {correct}")

    print(f"   - Total Neighbors: {len(neighbors_dict[node])}")
    print(f"   - Labeled Neighbors: {len(neighbor_labels)}")
    for lbl, count in label_counts.items():
        print(f"   - Class {lbl}: {count} neighbors")
        # ✅ Update Labeled Neighbor Score for Unlabeled Neighbors
        for neighbor in neighbors_dict[node]:
            if y_pred[neighbor] == -1:
                old_entry = next((entry for entry in ordered_set if entry[1] == neighbor), None)

                if old_entry:
                    ordered_set.discard(old_entry)

                num_labeled_by_train = sum(1 for n in neighbors_dict[neighbor] if y_pred[n] != -1 and n in train_labeled_nodes)
                num_labeled_by_propagation = sum(1 for n in neighbors_dict[neighbor] if y_pred[n] != -1 and n not in train_labeled_nodes)
                total_neighbors = len(neighbors_dict[neighbor])

                new_weighted_score = (a4*num_labeled_by_propagation + a5 * num_labeled_by_train) / total_neighbors if total_neighbors > 0 else 0

                ordered_set.add((-new_weighted_score, neighbor))
    print("\n\n\n")

# ✅ Evaluate Accuracy
test_indices = [i for i in range(data.num_nodes) if i not in train_indices]
y_true = data.y[test_indices]
y_pred_test = y_pred[test_indices]

valid_idx = [i for i in range(len(y_pred_test)) if y_pred_test[i] != -1]
if valid_idx:
    final_accuracy = accuracy_score(y_true[valid_idx], y_pred_test[valid_idx])
    print(f"\n🎯 Label Propagation Accuracy: {final_accuracy:.4f}")
else:
    print("\n❌ No valid predictions were made!")
# Out:
# ✅ Loaded  dataset with 251 nodes, 916 edges
#    - Features: 1703
#    - Number of Classes: 5
#    - Number of Components: 1
# 41 1
# 77 1
# 4 1
# 24 1
# 17 1
# 1 -23.995182037353516
# 2 -20.064606257847377
# 0 -22.474420729137602
# 3 -25.738169624691917
# 4 -30.622625623430523
#
# 🔹 Labelling Node 9
#    -> Predicted Label: 2 | True Label: 0 ❌
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 4: 1 neighbors
#
#
#
#
# 41 1
# 78 1
# 4 1
# 24 1
# 17 1
# 1 -23.060985565185547
# 2 -20.613751002720424
# 0 -23.81138819739932
# 3 -32.58060164678665
# 4 -24.687973294939315
#
# 🔹 Labelling Node 36
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 3: 1 neighbors
#
#
#
#
# 41 1
# 79 1
# 4 1
# 24 1
# 17 1
# 1 -29.629764556884766
# 2 -29.35751015799386
# 0 -28.082557859874907
# 3 -30.978651955014183
# 4 -29.334722791399276
#
# 🔹 Labelling Node 38
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 2: 1 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 41 1
# 79 1
# 5 1
# 24 1
# 17 1
# 1 -21.21602439880371
# 2 -15.318457194737025
# 0 -19.642227354503813
# 3 -22.806330635434104
# 4 -27.498598371233257
#
# 🔹 Labelling Node 39
#    -> Predicted Label: 2 | True Label: 3 ❌
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 4: 1 neighbors
#
#
#
#
# 41 1
# 80 1
# 5 1
# 24 1
# 17 1
# 1 -21.01300048828125
# 2 -15.289895602634974
# 0 -19.685442152477446
# 3 -29.04919905889602
# 4 -21.490211759294784
#
# 🔹 Labelling Node 61
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 3: 1 neighbors
#
#
#
#
# 41 1
# 81 1
# 5 1
# 24 1
# 17 1
# 1 -25.177478790283203
# 2 -20.025751658848353
# 0 -24.097397032238188
# 3 -31.30321402776809
# 4 -24.96437100001744
#
# 🔹 Labelling Node 73
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 3: 1 neighbors
#
#
#
#
# 41 1
# 82 1
# 5 1
# 24 1
# 17 1
# 1 -24.146793365478516
# 2 -22.12894684927804
# 0 -22.49278468177432
# 3 -25.500586464291526
# 4 -23.83589199611119
#
# 🔹 Labelling Node 74
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 1: 1 neighbors
#    - Class 2: 1 neighbors
#
#
#
#
# 41 1
# 83 1
# 5 1
# 24 1
# 17 1
# 1 -24.129438400268555
# 2 -22.87795693533761
# 0 -23.107254209972563
# 3 -26.35042281377883
# 4 -24.658668790544784
#
# 🔹 Labelling Node 83
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 2: 1 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 41 1
# 84 1
# 5 1
# 24 1
# 17 1
# 1 -23.6873836517334
# 2 -26.373417445591517
# 0 -23.715217771984282
# 3 -26.282481148129417
# 4 -24.774669919695175
#
# 🔹 Labelling Node 91
#    -> Predicted Label: 1 | True Label: 1 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 2: 3 neighbors
#
#
#
#
# 42 1
# 84 1
# 5 1
# 24 1
# 17 1
# 1 -19.728364944458008
# 2 -14.3474212374006
# 0 -19.587547483898344
# 3 -28.978817894345237
# 4 -20.571192060198104
#
# 🔹 Labelling Node 106
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 3: 1 neighbors
#
#
#
#
# 42 1
# 85 1
# 5 1
# 24 1
# 17 1
# 1 -24.390607833862305
# 2 -27.9669919695173
# 0 -24.553184690929594
# 3 -27.4920167468843
# 4 -25.96017292567662
#
# 🔹 Labelling Node 110
#    -> Predicted Label: 1 | True Label: 1 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 2: 1 neighbors
#
#
#
#
# 43 1
# 85 1
# 5 1
# 24 1
# 17 1
# 1 -32.196006774902344
# 2 -29.061018535069056
# 0 -30.952530088878813
# 3 -33.589693977719264
# 4 -34.160055433000835
#
# 🔹 Labelling Node 118
#    -> Predicted Label: 2 | True Label: 3 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 3: 1 neighbors
#    - Class 4: 1 neighbors
#
#
#
#
# 43 1
# 86 1
# 5 1
# 24 1
# 17 1
# 1 -22.08161163330078
# 2 -18.231997081211635
# 0 -22.082935514904204
# 3 -31.389117195492698
# 4 -23.217798505510604
#
# 🔹 Labelling Node 136
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 3: 1 neighbors
#
#
#
#
# 43 1
# 87 1
# 5 1
# 24 1
# 17 1
# 1 -27.843503952026367
# 2 -18.12313515799386
# 0 -21.799318495250883
# 3 -25.35082907903762
# 4 -22.834015165056503
#
# 🔹 Labelling Node 142
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 1: 1 neighbors
#
#
#
#
# 43 1
# 88 1
# 5 1
# 24 1
# 17 1
# 1 -27.201562881469727
# 2 -23.981997081211635
# 0 -26.551204863048735
# 3 -28.567494346981956
# 4 -33.81910923549107
#
# 🔹 Labelling Node 143
#    -> Predicted Label: 2 | True Label: 0 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 4: 2 neighbors
#
#
#
#
# 43 1
# 89 1
# 5 1
# 24 1
# 17 1
# 1 -24.89777946472168
# 2 -23.71687180655343
# 0 -23.45927638099307
# 3 -26.867962791806175
# 4 -25.236442838396346
#
# 🔹 Labelling Node 150
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 2: 1 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 43 1
# 89 1
# 6 1
# 24 1
# 17 1
# 1 -22.294456481933594
# 2 -24.299583980015345
# 0 -22.569814863659087
# 3 -25.703581764584495
# 4 -24.8501398903983
#
# 🔹 Labelling Node 152
#    -> Predicted Label: 1 | True Label: 1 ✅
#    - Total Neighbors: 6
#    - Labeled Neighbors: 6
#    - Class 2: 5 neighbors
#    - Class 4: 1 neighbors
#
#
#
#
# 44 1
# 89 1
# 6 1
# 24 1
# 17 1
# 1 -19.645851135253906
# 2 -15.088169642857142
# 0 -19.127214613414946
# 3 -23.386790230160667
# 4 -26.23719433375767
#
# 🔹 Labelling Node 162
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 4: 1 neighbors
#
#
#
#
# 44 1
# 90 1
# 6 1
# 24 1
# 17 1
# 1 -21.264793395996094
# 2 -15.901629039219447
# 0 -20.040895643688383
# 3 -23.206156685238792
# 4 -28.03051403590611
#
# 🔹 Labelling Node 185
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 4: 1 neighbors
#
#
#
#
# 44 1
# 91 1
# 6 1
# 24 1
# 17 1
# 1 -24.305675506591797
# 2 -22.92059189932687
# 0 -21.104738417125883
# 3 -26.529822304135276
# 4 -24.72347858973912
#
# 🔹 Labelling Node 215
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 1: 1 neighbors
#    - Class 2: 1 neighbors
#
#
#
#
# 44 1
# 91 1
# 7 1
# 24 1
# 17 1
# 1 -28.236448287963867
# 2 -17.663761683872767
# 0 -21.098167601085844
# 3 -24.261776878720237
# 4 -23.378492627825057
#
# 🔹 Labelling Node 221
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 1: 1 neighbors
#
#
#
#
# 44 1
# 92 1
# 7 1
# 24 1
# 17 1
# 1 -25.83851432800293
# 2 -15.597260066441127
# 0 -19.158092680431547
# 3 -23.565121605282737
# 4 -20.973970685686385
#
# 🔹 Labelling Node 247
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 1: 1 neighbors
#
#
#
#
# 44 1
# 93 1
# 7 1
# 24 1
# 17 1
# 1 -35.74880599975586
# 2 -33.14355713980539
# 0 -33.28621310279483
# 3 -32.26330275762649
# 4 -33.596510205950054
#
# 🔹 Labelling Node 178
#    -> Predicted Label: 3 | True Label: 3 ✅
#    - Total Neighbors: 9
#    - Labeled Neighbors: 8
#    - Class 2: 3 neighbors
#    - Class 4: 1 neighbors
#    - Class 3: 1 neighbors
#    - Class 1: 3 neighbors
#
#
#
#
# 44 1
# 93 1
# 7 1
# 25 1
# 17 1
# 1 -25.222831344604494
# 2 -21.626748057774137
# 0 -21.442230406261626
# 3 -25.75140280950637
# 4 -23.93465260096959
#
# 🔹 Labelling Node 0
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 6
#    - Labeled Neighbors: 5
#    - Class 2: 2 neighbors
#    - Class 1: 3 neighbors
#
#
#
#
# 44 1
# 93 1
# 8 1
# 25 1
# 17 1
# 1 -23.66143035888672
# 2 -17.18692261832101
# 0 -19.972061338878813
# 3 -27.4906682514009
# 4 -22.084280286516464
#
# 🔹 Labelling Node 128
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 4
#    - Labeled Neighbors: 4
#    - Class 3: 2 neighbors
#    - Class 1: 2 neighbors
#
#
#
#
# 44 1
# 94 1
# 8 1
# 25 1
# 17 1
# 1 -23.557523727416992
# 2 -28.113697596958705
# 0 -23.77336329505557
# 3 -27.84822554815383
# 4 -26.239074979509628
#
# 🔹 Labelling Node 89
#    -> Predicted Label: 1 | True Label: 1 ✅
#    - Total Neighbors: 5
#    - Labeled Neighbors: 4
#    - Class 2: 4 neighbors
#
#
#
#
# 45 1
# 94 1
# 8 1
# 25 1
# 17 1
# 1 -24.588043212890625
# 2 -24.33879143851144
# 0 -22.94052332923526
# 3 -29.16894431341262
# 4 -25.754352842058456
#
# 🔹 Labelling Node 199
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 5
#    - Labeled Neighbors: 4
#    - Class 2: 2 neighbors
#    - Class 3: 1 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 45 1
# 94 1
# 9 1
# 25 1
# 17 1
# 1 -27.221132278442383
# 2 -18.25292260306222
# 0 -21.62150019691104
# 3 -26.454735710507347
# 4 -23.688576017107284
#
# 🔹 Labelling Node 11
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 4
#    - Labeled Neighbors: 3
#    - Class 1: 2 neighbors
#    - Class 3: 1 neighbors
#
#
#
#
# 45 1
# 95 1
# 9 1
# 25 1
# 17 1
# 1 -32.723615646362305
# 2 -35.80759484427316
# 0 -31.635025206066313
# 3 -35.452202751522975
# 4 -34.46991947719029
#
# 🔹 Labelling Node 35
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 4
#    - Labeled Neighbors: 3
#    - Class 2: 2 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 45 1
# 95 1
# 10 1
# 25 1
# 17 1
# 1 -25.401168823242188
# 2 -29.840262004307338
# 0 -26.15600604102725
# 3 -29.28533835638137
# 4 -28.15783909388951
#
# 🔹 Labelling Node 52
#    -> Predicted Label: 1 | True Label: 1 ✅
#    - Total Neighbors: 11
#    - Labeled Neighbors: 8
#    - Class 2: 8 neighbors
#
#
#
#
# 46 1
# 95 1
# 10 1
# 25 1
# 17 1
# 1 -25.116390632180607
# 2 -23.824874211159074
# 0 -23.762097910605892
# 3 -27.119972957749994
# 4 -25.327260906956777
#
# 🔹 Labelling Node 98
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 122
#    - Labeled Neighbors: 85
#    - Class 2: 52 neighbors
#    - Class 1: 11 neighbors
#    - Class 3: 14 neighbors
#    - Class 0: 3 neighbors
#    - Class 4: 5 neighbors
#
#
#
#
# 46 1
# 95 1
# 11 1
# 25 1
# 17 1
# 1 -25.65070343017578
# 2 -22.0180059160505
# 0 -27.253917875744047
# 3 -29.265694572812034
# 4 -28.068914685930526
#
# 🔹 Labelling Node 68
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 0: 1 neighbors
#    - Class 3: 1 neighbors
#    - Class 4: 1 neighbors
#
#
#
#
# 46 1
# 96 1
# 11 1
# 25 1
# 17 1
# 1 -27.46657943725586
# 2 -24.30989510672433
# 0 -30.520761671520415
# 3 -29.20567412603469
# 4 -30.186291013445175
#
# 🔹 Labelling Node 138
#    -> Predicted Label: 2 | True Label: 0 ❌
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 0: 2 neighbors
#    - Class 4: 1 neighbors
#
#
#
#
# 46 1
# 97 1
# 11 1
# 25 1
# 17 1
# 1 -21.874649047851562
# 2 -16.251886912754603
# 0 -23.971071424938383
# 3 -26.545119240170433
# 4 -22.148985181535995
#
# 🔹 Labelling Node 2
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 0: 1 neighbors
#    - Class 3: 1 neighbors
#
#
#
#
# 46 1
# 98 1
# 11 1
# 25 1
# 17 1
# 1 -21.437944412231445
# 2 -15.90616852896554
# 0 -23.467268171764555
# 3 -26.615534736996604
# 4 -21.995483670915878
#
# 🔹 Labelling Node 10
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 0: 1 neighbors
#    - Class 3: 1 neighbors
#
#
#
#
# 46 1
# 99 1
# 11 1
# 25 1
# 17 1
# 1 -23.234607696533203
# 2 -19.8286805834089
# 0 -23.963382902599516
# 3 -26.221371605282737
# 4 -25.162292752947128
#
# 🔹 Labelling Node 69
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 5
#    - Labeled Neighbors: 4
#    - Class 0: 1 neighbors
#    - Class 2: 1 neighbors
#    - Class 4: 1 neighbors
#    - Class 3: 1 neighbors
#
#
#
#
# 46 1
# 100 1
# 11 1
# 25 1
# 17 1
# 1 -23.3779354095459
# 2 -21.153647014072963
# 0 -23.484705152965727
# 3 -25.207350685482933
# 4 -24.63264492579869
#
# 🔹 Labelling Node 29
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 7
#    - Labeled Neighbors: 6
#    - Class 0: 1 neighbors
#    - Class 2: 3 neighbors
#    - Class 4: 1 neighbors
#    - Class 3: 1 neighbors
#
#
#
#
# 46 1
# 101 1
# 11 1
# 25 1
# 17 1
# 1 -19.6512508392334
# 2 -18.72474534170968
# 0 -19.361025038219633
# 3 -23.548769905453636
# 4 -22.49117115565709
#
# 🔹 Labelling Node 103
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 2: 2 neighbors
#    - Class 4: 1 neighbors
#
#
#
#
# 46 1
# 102 1
# 11 1
# 25 1
# 17 1
# 1 -26.8809871673584
# 2 -15.768957683018275
# 0 -20.226932707287016
# 3 -23.7462892078218
# 4 -21.81137493678502
#
# 🔹 Labelling Node 70
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 1: 2 neighbors
#
#
#
#
# 46 1
# 103 1
# 11 1
# 25 1
# 17 1
# 1 -30.23869514465332
# 2 -23.466190883091517
# 0 -29.553104582287016
# 3 -26.566943123227073
# 4 -26.98705509730748
#
# 🔹 Labelling Node 137
#    -> Predicted Label: 2 | True Label: 3 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 1: 1 neighbors
#    - Class 0: 1 neighbors
#
#
#
#
# 46 1
# 104 1
# 11 1
# 25 1
# 17 1
# 1 -29.3056640625
# 2 -26.031599589756556
# 0 -31.343321028209868
# 3 -29.94458480108352
# 4 -32.20295361110142
#
# 🔹 Labelling Node 187
#    -> Predicted Label: 2 | True Label: 0 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 0: 1 neighbors
#    - Class 4: 1 neighbors
#
#
#
#
# 46 1
# 105 1
# 11 1
# 25 1
# 17 1
# 1 -27.354328155517578
# 2 -22.996679850987025
# 0 -23.753801527477446
# 3 -24.792000725155784
# 4 -24.75534466334752
#
# 🔹 Labelling Node 223
#    -> Predicted Label: 2 | True Label: 3 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 1: 1 neighbors
#    - Class 2: 1 neighbors
#
#
#
#
# 46 1
# 106 1
# 11 1
# 25 1
# 17 1
# 1 -20.441301345825195
# 2 -24.0005613054548
# 0 -21.107176008678618
# 3 -25.332838966732933
# 4 -23.065101896013534
#
# 🔹 Labelling Node 245
#    -> Predicted Label: 1 | True Label: 1 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 2
#    - Class 2: 2 neighbors
#
#
#
#
# 47 1
# 106 1
# 11 1
# 25 1
# 17 1
# 1 -27.60611343383789
# 2 -29.580311366489955
# 0 -27.024042311168852
# 3 -31.049035026913597
# 4 -28.758081708635604
#
# 🔹 Labelling Node 5
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 10
#    - Labeled Neighbors: 6
#    - Class 3: 1 neighbors
#    - Class 2: 4 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 47 1
# 106 1
# 12 1
# 25 1
# 17 1
# 1 -27.60611343383789
# 2 -29.580311366489955
# 0 -24.77079981849307
# 3 -31.049035026913597
# 4 -28.758081708635604
#
# 🔹 Labelling Node 97
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 10
#    - Labeled Neighbors: 6
#    - Class 3: 1 neighbors
#    - Class 2: 4 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 47 1
# 106 1
# 13 1
# 25 1
# 17 1
# 1 -27.61197280883789
# 2 -29.46388680594308
# 0 -23.33375948951358
# 3 -30.986359550839378
# 4 -28.679374967302596
#
# 🔹 Labelling Node 115
#    -> Predicted Label: 0 | True Label: 1 ❌
#    - Total Neighbors: 10
#    - Labeled Neighbors: 6
#    - Class 3: 1 neighbors
#    - Class 2: 4 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 47 1
# 106 1
# 14 1
# 25 1
# 17 1
# 1 -29.277708053588867
# 2 -23.843000956944056
# 0 -29.474069776989165
# 3 -28.199091865902854
# 4 -29.662519727434432
#
# 🔹 Labelling Node 132
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 4
#    - Labeled Neighbors: 3
#    - Class 1: 1 neighbors
#    - Class 0: 1 neighbors
#    - Class 4: 1 neighbors
#
#
#
#
# 47 1
# 107 1
# 14 1
# 25 1
# 17 1
# 1 -24.651107788085938
# 2 -22.780817576817103
# 0 -26.703691664196196
# 3 -28.080717995053245
# 4 -26.68430164882115
#
# 🔹 Labelling Node 92
#    -> Predicted Label: 2 | True Label: 4 ❌
#    - Total Neighbors: 6
#    - Labeled Neighbors: 4
#    - Class 4: 1 neighbors
#    - Class 0: 1 neighbors
#    - Class 2: 1 neighbors
#    - Class 3: 1 neighbors
#
#
#
#
# 47 1
# 108 1
# 14 1
# 25 1
# 17 1
# 1 -22.211410522460938
# 2 -18.9945741380964
# 0 -24.303861799694243
# 3 -25.84740348089309
# 4 -22.802007947649276
#
# 🔹 Labelling Node 163
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 0: 1 neighbors
#    - Class 2: 1 neighbors
#    - Class 3: 1 neighbors
#
#
#
#
# 47 1
# 109 1
# 14 1
# 25 1
# 17 1
# 1 -27.266630172729492
# 2 -27.094029017857142
# 0 -29.171112242199126
# 3 -30.421994163876487
# 4 -28.817659650530135
#
# 🔹 Labelling Node 28
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 5
#    - Labeled Neighbors: 5
#    - Class 0: 2 neighbors
#    - Class 2: 2 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 47 1
# 110 1
# 14 1
# 25 1
# 17 1
# 1 -25.289630889892578
# 2 -23.248529979160853
# 0 -26.872478666759672
# 3 -29.72980208623977
# 4 -25.55055836268834
#
# 🔹 Labelling Node 63
#    -> Predicted Label: 2 | True Label: 4 ❌
#    - Total Neighbors: 5
#    - Labeled Neighbors: 4
#    - Class 0: 1 neighbors
#    - Class 3: 2 neighbors
#    - Class 2: 1 neighbors
#
#
#
#
# 47 1
# 111 1
# 14 1
# 25 1
# 17 1
# 1 -26.65947151184082
# 2 -24.234196254185267
# 0 -26.99697512672061
# 3 -27.3168401264009
# 4 -25.901855741228378
#
# 🔹 Labelling Node 78
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 0: 1 neighbors
#    - Class 1: 1 neighbors
#    - Class 2: 1 neighbors
#
#
#
#
# 47 1
# 112 1
# 14 1
# 25 1
# 17 1
# 1 -23.739980697631836
# 2 -23.69233567374093
# 0 -23.61599368140811
# 3 -25.197064354306175
# 4 -25.981594358171737
#
# 🔹 Labelling Node 50
#    -> Predicted Label: 0 | True Label: 4 ❌
#    - Total Neighbors: 6
#    - Labeled Neighbors: 3
#    - Class 4: 1 neighbors
#    - Class 2: 2 neighbors
#
#
#
#
# 47 1
# 112 1
# 15 1
# 25 1
# 17 1
# 1 -29.294212341308594
# 2 -20.750238963535853
# 0 -23.704008284069243
# 3 -26.92346854436965
# 4 -24.648363385881698
#
# 🔹 Labelling Node 66
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 1
#    - Class 1: 1 neighbors
#
#
#
#
# 47 1
# 113 1
# 15 1
# 25 1
# 17 1
# 1 -23.84414291381836
# 2 -17.948351451328822
# 0 -20.49951190040225
# 3 -24.04002471197219
# 4 -21.43037441798619
#
# 🔹 Labelling Node 3
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 2: 1 neighbors
#    - Class 1: 2 neighbors
#
#
#
#
# 47 1
# 114 1
# 15 1
# 25 1
# 17 1
# 1 -29.303569793701172
# 2 -22.93311745779855
# 0 -23.579437437511626
# 3 -28.669972374325706
# 4 -26.97182491847447
#
# 🔹 Labelling Node 148
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 1
#    - Class 1: 1 neighbors
#
#
#
#
# 47 1
# 115 1
# 15 1
# 25 1
# 17 1
# 1 -23.79987144470215
# 2 -21.992598124912806
# 0 -24.464218321300688
# 3 -33.66738028753372
# 4 -25.93093708583287
#
# 🔹 Labelling Node 158
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 1
#    - Class 3: 1 neighbors
#
#
#
#
# 47 1
# 116 1
# 15 1
# 25 1
# 17 1
# 1 -20.19796371459961
# 2 -16.410416194370814
# 0 -22.874448957897368
# 3 -26.358189537411643
# 4 -23.030102048601425
#
# 🔹 Labelling Node 186
#    -> Predicted Label: 2 | True Label: 4 ❌
#    - Total Neighbors: 6
#    - Labeled Neighbors: 3
#    - Class 3: 1 neighbors
#    - Class 0: 1 neighbors
#    - Class 4: 1 neighbors
#
#
#
#
# 47 1
# 117 1
# 15 1
# 25 1
# 17 1
# 1 -26.144094467163086
# 2 -24.00931794302804
# 0 -27.587465467907133
# 3 -26.092537834530784
# 4 -27.63136318751744
#
# 🔹 Labelling Node 238
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 2: 1 neighbors
#    - Class 0: 1 neighbors
#    - Class 4: 1 neighbors
#
#
#
#
# 47 1
# 118 1
# 15 1
# 25 1
# 17 1
# 1 -26.978422164916992
# 2 -25.568234034946986
# 0 -26.893722715831938
# 3 -28.04424948919387
# 4 -26.736326490129745
#
# 🔹 Labelling Node 229
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 4
#    - Labeled Neighbors: 4
#    - Class 0: 1 neighbors
#    - Class 2: 2 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 47 1
# 119 1
# 15 1
# 25 1
# 17 1
# 1 -23.17133903503418
# 2 -16.096493312290736
# 0 -23.56473177955264
# 3 -24.307118370419456
# 4 -21.622877393450057
#
# 🔹 Labelling Node 22
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 0: 1 neighbors
#    - Class 1: 1 neighbors
#    - Class 2: 1 neighbors
#
#
#
#
# 47 1
# 120 1
# 15 1
# 25 1
# 17 1
# 1 -23.724933624267578
# 2 -19.479916163853236
# 0 -26.576135817028227
# 3 -27.998715355282737
# 4 -24.209261213030135
#
# 🔹 Labelling Node 153
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 2: 1 neighbors
#    - Class 0: 1 neighbors
#    - Class 3: 1 neighbors
#
#
#
#
# 47 1
# 121 1
# 15 1
# 25 1
# 17 1
# 1 -29.659626007080078
# 2 -23.29948479788644
# 0 -29.689523878551665
# 3 -28.234797432309104
# 4 -27.712408338274276
#
# 🔹 Labelling Node 169
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 2: 1 neighbors
#    - Class 0: 1 neighbors
#    - Class 1: 1 neighbors
#
#
#
#
# 47 1
# 122 1
# 15 1
# 25 1
# 17 1
# 1 -24.69433675493513
# 2 -19.171429225376674
# 0 -27.158524831136067
# 3 -25.646641685849143
# 4 -24.05652645656041
#
# 🔹 Labelling Node 32
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 7
#    - Labeled Neighbors: 7
#    - Class 0: 5 neighbors
#    - Class 1: 2 neighbors
#
#
#
#
# 47 1
# 123 1
# 15 1
# 25 1
# 17 1
# 1 -20.627492904663086
# 2 -15.725107737949916
# 0 -26.725799742199126
# 3 -23.333920433407737
# 4 -21.704527173723495
#
# 🔹 Labelling Node 14
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 47 1
# 124 1
# 15 1
# 25 1
# 17 1
# 1 -22.70416831970215
# 2 -20.742168971470424
# 0 -25.340002241588774
# 3 -24.051068260556175
# 4 -22.847851072038925
#
# 🔹 Labelling Node 15
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 2: 1 neighbors
#    - Class 0: 1 neighbors
#
#
#
#
# 47 1
# 125 1
# 15 1
# 25 1
# 17 1
# 1 -23.116439819335938
# 2 -19.438236781529017
# 0 -29.419756117321196
# 3 -26.15857405889602
# 4 -24.244694028581893
#
# 🔹 Labelling Node 40
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 47 1
# 126 1
# 15 1
# 25 1
# 17 1
# 1 -22.42333984375
# 2 -17.950964518955775
# 0 -28.412336531139555
# 3 -25.047656013852073
# 4 -23.69313648768834
#
# 🔹 Labelling Node 55
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 47 1
# 127 1
# 15 1
# 25 1
# 17 1
# 1 -25.249446868896484
# 2 -21.828861781529017
# 0 -31.274322691417876
# 3 -26.74442382085891
# 4 -25.89397648402623
#
# 🔹 Labelling Node 72
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 47 1
# 128 1
# 15 1
# 25 1
# 17 1
# 1 -22.524837493896484
# 2 -18.827578135899135
# 0 -28.561432066417876
# 3 -25.34703154790969
# 4 -24.166744504656112
#
# 🔹 Labelling Node 80
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 47 1
# 129 1
# 15 1
# 25 1
# 17 1
# 1 -25.348114013671875
# 2 -24.911907741001674
# 0 -28.151544752575102
# 3 -27.11060042608352
# 4 -25.486454282488143
#
# 🔹 Labelling Node 131
#    -> Predicted Label: 2 | True Label: 0 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 2: 1 neighbors
#    - Class 0: 1 neighbors
#
#
#
#
# 47 1
# 130 1
# 15 1
# 25 1
# 17 1
# 1 -20.486858367919922
# 2 -15.705723353794642
# 0 -26.63586443946475
# 3 -23.597203209286643
# 4 -21.69395092555455
#
# 🔹 Labelling Node 134
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 47 1
# 131 1
# 15 1
# 25 1
# 17 1
# 1 -20.38188362121582
# 2 -15.166934558323451
# 0 -26.16211527869815
# 3 -23.04468245733352
# 4 -21.043911252702987
#
# 🔹 Labelling Node 135
#    -> Predicted Label: 2 | True Label: 0 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 0: 2 neighbors
#
#
#
#
# 47 1
# 132 1
# 15 1
# 25 1
# 17 1
# 1 -19.540884017944336
# 2 -15.313320704868861
# 0 -26.07182520911807
# 3 -23.71410269964309
# 4 -20.353025708879745
#
# 🔹 Labelling Node 141
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 0: 3 neighbors
#
#
#
#
# 47 1
# 133 1
# 15 1
# 25 1
# 17 1
# 1 -27.062559127807617
# 2 -26.615149089268275
# 0 -29.994516554332915
# 3 -26.936762764340354
# 4 -27.407957349504745
#
# 🔹 Labelling Node 144
#    -> Predicted Label: 2 | True Label: 3 ❌
#    - Total Neighbors: 4
#    - Labeled Neighbors: 3
#    - Class 0: 1 neighbors
#    - Class 2: 2 neighbors
#
#
#
#
# 47 1
# 134 1
# 15 1
# 25 1
# 17 1
# 1 -25.289501190185547
# 2 -30.079729625156947
# 0 -26.07568377540225
# 3 -28.960288002377464
# 4 -27.237568174089706
#
# 🔹 Labelling Node 108
#    -> Predicted Label: 1 | True Label: 1 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 2: 1 neighbors
#
#
#
#
# 48 1
# 134 1
# 15 1
# 25 1
# 17 1
# 1 -21.46660041809082
# 2 -16.399653026035853
# 0 -27.35532015845889
# 3 -23.79831214178176
# 4 -22.352299009050643
#
# 🔹 Labelling Node 174
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 48 1
# 135 1
# 15 1
# 25 1
# 17 1
# 1 -30.576248168945312
# 2 -27.661428996494838
# 0 -36.15304583594913
# 3 -29.897301628476097
# 4 -30.054550443376815
#
# 🔹 Labelling Node 218
#    -> Predicted Label: 2 | True Label: 3 ❌
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 48 1
# 136 1
# 15 1
# 25 1
# 17 1
# 1 -23.7485294342041
# 2 -19.366030284336635
# 0 -29.590917768932524
# 3 -25.703968956356956
# 4 -24.453314099993026
#
# 🔹 Labelling Node 227
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 48 1
# 137 1
# 15 1
# 25 1
# 17 1
# 1 -23.19870948791504
# 2 -18.757923671177455
# 0 -28.758167448497954
# 3 -24.681168510800315
# 4 -23.604788099016464
#
# 🔹 Labelling Node 230
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 0: 2 neighbors
#
#
#
#
# 48 1
# 138 1
# 15 1
# 25 1
# 17 1
# 1 -24.014116287231445
# 2 -20.814335414341517
# 0 -30.383085432506743
# 3 -27.47809310186477
# 4 -25.71295383998326
#
# 🔹 Labelling Node 235
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 48 1
# 139 1
# 15 1
# 25 1
# 17 1
# 1 -19.99672508239746
# 2 -15.444276400974818
# 0 -26.28214472816104
# 3 -23.67880530584426
# 4 -20.86879757472447
#
# 🔹 Labelling Node 236
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 0: 3 neighbors
#
#
#
#
# 48 1
# 140 1
# 15 1
# 25 1
# 17 1
# 1 -19.752952575683594
# 2 -15.578325816563197
# 0 -26.346965971447172
# 3 -23.975926353817893
# 4 -20.929441724504745
#
# 🔹 Labelling Node 246
#    -> Predicted Label: 2 | True Label: 2 ✅
#    - Total Neighbors: 3
#    - Labeled Neighbors: 3
#    - Class 0: 3 neighbors
#
#
#
#
# 48 1
# 141 1
# 15 1
# 25 1
# 17 1
# 1 -20.61184310913086
# 2 -22.518087932041713
# 0 -21.072038832164946
# 3 -24.206530525570823
# 4 -21.52407101222447
#
# 🔹 Labelling Node 248
#    -> Predicted Label: 1 | True Label: 2 ❌
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 2: 1 neighbors
#
#
#
#
# 49 1
# 141 1
# 15 1
# 25 1
# 17 1
# 1 -21.691429138183594
# 2 -19.443783351353236
# 0 -28.316530409313383
# 3 -26.04776854742141
# 4 -23.991291318620956
#
# 🔹 Labelling Node 82
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 1
#    - Class 0: 1 neighbors
#
#
#
#
# 49 1
# 142 1
# 15 1
# 25 1
# 17 1
# 1 -27.1469783782959
# 2 -27.699568339756556
# 0 -30.47825831458682
# 3 -28.822001411801292
# 4 -28.433300290788925
#
# 🔹 Labelling Node 25
#    -> Predicted Label: 1 | True Label: 3 ❌
#    - Total Neighbors: 4
#    - Labeled Neighbors: 2
#    - Class 2: 1 neighbors
#    - Class 0: 1 neighbors
#
#
#
#
# 50 1
# 142 1
# 15 1
# 25 1
# 17 1
# 1 -28.810945510864258
# 2 -24.750279017857142
# 0 -29.563217344738188
# 3 -29.5612248920259
# 4 -28.459451947893417
#
# 🔹 Labelling Node 113
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 2
#    - Labeled Neighbors: 2
#    - Class 1: 1 neighbors
#    - Class 0: 1 neighbors
#
#
#
#
# 50 1
# 143 1
# 15 1
# 25 1
# 17 1
# 1 -26.002309799194336
# 2 -16.500296183994838
# 0 -20.538154783703032
# 3 -24.25669188726516
# 4 -21.282198224748885
#
# 🔹 Labelling Node 228
#    -> Predicted Label: 2 | True Label: 1 ❌
#    - Total Neighbors: 1
#    - Labeled Neighbors: 1
#    - Class 1: 1 neighbors
#
#
#
#
#
# 🎯 Label Propagation Accuracy: 0.5455

# %%
import torch
import numpy as np
import random
from collections import Counter, defaultdict
from sortedcontainers import SortedSet
from sklearn.metrics import accuracy_score
import networkx as nx
from torch_geometric.utils import to_networkx

def predictclass(data, train_indices, test_indices, a1, a2, a3, a4, a5):
    data.edge_index = torch.cat([data.edge_index, data.edge_index.flip(0)], dim=1)
    train_indices = list(train_indices)
    test_indices = list(test_indices)

    # ✅ Remove duplicate edges
    data.edge_index = torch.unique(data.edge_index, dim=1)

    # ✅ Initialize Prediction Labels
    y_pred = np.full(data.num_nodes, -1, dtype=int)
    for idx in train_indices:
        y_pred[idx] = data.y[idx].item()

    # ✅ Compute Label Distribution
    total_label_counts = Counter(data.y.numpy())
    num_labels = len(set(data.y.numpy()))
    alpha = 1  # Laplace smoothing

    dataset_label_distribution = {
        lbl: (total_label_counts[lbl] + alpha) / (len(data.y) + alpha * num_labels)
        for lbl in total_label_counts.keys()
    }

    train_label_counts = Counter(y_pred[train_indices])

    train_label_distribution = {
        lbl: (train_label_counts.get(lbl, 0) + alpha) / (len(train_indices) + alpha * num_labels)
        for lbl in dataset_label_distribution.keys()
    }

    # ✅ Precompute Neighbors for Each Node
    A = torch.zeros((data.num_nodes, data.num_nodes))
    A[data.edge_index[0], data.edge_index[1]] = 1
    neighbors_dict = {i: set(np.where(A[i] == 1)[0]) for i in range(data.num_nodes)}

    # ✅ Track Instances Assigned to Each Label
    class_instances = defaultdict(set)
    for idx in train_indices:
        class_instances[data.y[idx].item()].add(idx)

    # ✅ Ordered Set for Managing Unlabeled Vertices
    ordered_set = SortedSet()
    train_labeled_nodes = set(train_indices)

    for node in range(data.num_nodes):
        if y_pred[node] == -1:
            labeled_neighbors = [n for n in neighbors_dict[node] if y_pred[n] != -1]
            num_labeled_by_train = sum(1 for n in labeled_neighbors if n in train_labeled_nodes)
            num_labeled_by_propagation = len(labeled_neighbors) - num_labeled_by_train
            total_neighbors = len(neighbors_dict[node])

            if total_neighbors > 0:
                weighted_score = (a4 * num_labeled_by_propagation + a5 * num_labeled_by_train) / total_neighbors
            else:
                weighted_score = 0

            ordered_set.add((-weighted_score, node))

    # ✅ Iteratively Label the Most Constrained Nodes
    while ordered_set:
        _, node = ordered_set.pop(0)

        if y_pred[node] != -1:
            continue  # Skip already labeled nodes

        # Get labeled neighbors
        neighbor_labels = [y_pred[n] for n in neighbors_dict[node] if y_pred[n] != -1]
        label_counts = Counter(neighbor_labels)

        # 🚨 If this node has 0 labeled neighbors
        if not neighbor_labels:
            continue

        # Compute Neighbor Label Distribution
        neighbor_label_counts = Counter(neighbor_labels)
        total_labeled_neighbors = len(neighbor_labels)

        if total_labeled_neighbors > 0:
            neighbor_label_distribution = {
                lbl: neighbor_label_counts[lbl] / total_labeled_neighbors for lbl in neighbor_label_counts.keys()
            }
        else:
            neighbor_label_distribution = {lbl: 0 for lbl in dataset_label_distribution.keys()}

        feature_diffs = {}

        for lbl in dataset_label_distribution.keys():
            if class_instances[lbl]:  # Only compute if we have instances of the label
                instance_features = data.x[list(class_instances[lbl])]
                node_feature = data.x[node].unsqueeze(0)

                if instance_features.numel() > 0:  # ✅ Ensure instance_features is not empty
                    avg_distance = torch.mean(torch.norm(instance_features - node_feature, dim=1)).item()
                else:
                    avg_distance = 0  # ✅ Avoid empty slice issue
                feature_diffs[lbl] = avg_distance
            else:
                feature_diffs[lbl] = 0  # No penalty if no instances exist

        # ✅ Select the Best Label Based on the Adjusted Score
        best_label_candidates = []
        max_value = float('-inf')

        for lbl in dataset_label_distribution.keys():
            score = (
                a1 * train_label_distribution.get(lbl, 0)
                + a2 * neighbor_label_distribution.get(lbl, 0)
                + a3 * feature_diffs[lbl]  # Penalize by average feature distance
            )

            if score - max_value > 0.01:
                best_label_candidates = [lbl]
                max_value = score
            elif abs(score - max_value) <= 0.01:
                best_label_candidates.append(lbl)

        best_label = random.choice(best_label_candidates)
        y_pred[node] = best_label
        class_instances[best_label].add(node)  # Track newly labeled nodes

        # ✅ Update Labeled Neighbor Score for Unlabeled Neighbors
        for neighbor in neighbors_dict[node]:
            if y_pred[neighbor] == -1:
                old_entry = next((entry for entry in ordered_set if entry[1] == neighbor), None)

                if old_entry:
                    ordered_set.discard(old_entry)

                num_labeled_by_train = sum(1 for n in neighbors_dict[neighbor] if y_pred[n] != -1 and n in train_labeled_nodes)
                num_labeled_by_propagation = sum(1 for n in neighbors_dict[neighbor] if y_pred[n] != -1 and n not in train_labeled_nodes)
                total_neighbors = len(neighbors_dict[neighbor])

                new_weighted_score = (a4 * num_labeled_by_propagation + a5 * num_labeled_by_train) / total_neighbors if total_neighbors > 0 else 0

                ordered_set.add((-new_weighted_score, neighbor))

    # ✅ Convert to PyTorch Tensor for Neural Network
    y_pred_test = torch.tensor(y_pred[test_indices], dtype=torch.float)

    # ✅ Compute Initial Classification Accuracy
    y_true = data.y[test_indices]
    valid_idx = [i for i in range(len(y_pred_test)) if y_pred_test[i] != -1]
    if valid_idx:
        initial_accuracy = accuracy_score(y_true[valid_idx], y_pred_test[valid_idx])
    else:
        initial_accuracy = 0.0  # No valid predictions

    return y_pred_test, initial_accuracy

# %%
data = dataset[0]



# Count occurrences of each class label
class_counts = torch.bincount(data.y)

# Print the number of elements in each class
for class_id, count in enumerate(class_counts):
    print(f"Class {class_id}: {count} elements")
a1=0.5
a2=-6
a3=-2
a4=1
a5=3
indices = np.arange(data.num_nodes)  # NumPy array of indices [0, 1, 2, ..., num_nodes-1]

train_idx, test_idx = train_test_split(indices, test_size=0.3)

# Further split train_idx into train and validation sets (e.g., 20% of train goes to validation)
train_idx, val_idx = train_test_split(train_idx, test_size=0.3)
print(predictclass(data,train_idx,valid_idx,a1,a2,a3,a4,a5))
# Out:
# Class 0: 10 elements
# Class 1: 70 elements
# Class 2: 118 elements
# Class 3: 32 elements
# Class 4: 21 elements
# (tensor([1., 2., 2., 2., 2., 1., 1., 1., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#         2., 2., 2., 1., 2., 2., 1., 3., 2., 3., 0., 2., 2., 2., 2., 2., 1., 1.,
#         4., 3., 1., 2., 2., 0., 2., 2., 4., 2., 4., 0., 0., 2., 4., 4., 1., 1.,
#         3., 2., 2., 2., 0., 2., 1., 2., 2., 4., 4., 2., 0., 2., 2., 2., 2., 2.,
#         2., 2., 1., 3., 2., 2., 1., 4., 2., 2., 2., 1., 2., 2., 2., 1.]), 0.7954545454545454)

# %%
from sklearn.model_selection import train_test_split
from scipy.optimize import minimize
import warnings
warnings.simplefilter("error", RuntimeWarning)  # Convert warnings to errors
#dataset = WebKB(root='data', name='Cornell')
#dataset = WebKB(root='data', name='texas')
#dataset = WikipediaNetwork(root='data', name='chameleon')
#dataset = WikipediaNetwork(root='data', name='squirrel')
#dataset = WebKB(root='data', name='Wisconsin')


data = dataset[0]

num_nodes = data.x.shape[0]
indices = np.arange(num_nodes)

# Split into training (70%) and testing (30%) randomly
from sklearn.model_selection import train_test_split
random_seed = 42
train_idx, test_idx = train_test_split(indices, test_size=0.3, random_state=random_seed)
train_idx, val_idx = train_test_split(train_idx, test_size=0.3, random_state=random_seed)


# Function to optimize (negate accuracy since we minimize)
# Function to optimize (maximize train accuracy by minimizing negative accuracy)

def random_search(model,data, train_idx,val_idx, num_samples=100):
    best_params = None
    best_score = float('-inf')

    for _ in range(num_samples):
        a1 = random.uniform(0, 10)     # a1 must be positive
        a2 = random.uniform(-10, -0.01)  # a2 must be negative
        a3 = random.uniform(-10, -0.01)  # a3 must be negative
        a5 = random.uniform(0, 10)     # a5 must be positive
        a4 = random.uniform(0,a5 )    # a4 must be positive and a4 <= a5

        params = [a1, a2, a3, a4, a5]


        _,score = model(data,train_idx,val_idx,params[0],params[1],params[2],params[3],params[4])
        if score > best_score:
            best_score = score
            best_params = params

    return best_params, best_score



# Initial guesses for a1, a2, a3, a4, a5
#initial_params = [0.5,-5,-2,1,3]

# Bounds for parameters
 # Adjust bounds as needed

# Optimize using scipy
result = random_search(predictclass,data,train_idx,val_idx,num_samples=20)[0]
#print(result)
# Get best parameters
best_a1, best_a2, best_a3, best_a4, best_a5 = result[0],result[1],result[2],result[3],result[4]

# Evaluate on test set
predicted_classes, final_accuracy = predictclass(data,train_idx,test_idx, best_a1, best_a2, best_a3, best_a4, best_a5)

# Print results
print("Optimal Parameters:", result)
print("Final Accuracy on Test Data:", final_accuracy)
# Out:
# Optimal Parameters: [2.2843761576408483, -9.997975731354979, -6.203901819409156, 0.5361587687322146, 4.720123876503211]
# Final Accuracy on Test Data: 0.631578947368421

# %%
# !pip install scikit-optimize

from skopt import gp_minimize
from skopt.space import Real
import random

def bayesian_optimization(model, data, train_idx, val_idx, num_calls=50):
    """
    Bayesian Optimization to find best hyperparameters (a1, a2, a3, a4, a5)
    that maximize the validation accuracy.
    """

    # Define the search space for a1, a2, a3, a4, a5
    search_space = [
        Real(0, 10, name="a1"),        # a1 must be positive
        Real(-10, -0.01, name="a2"),   # a2 must be negative
        Real(-10, -0.01, name="a3"),   # a3 must be negative
        Real(0, 10, name="a5"),        # a5 must be positive
        Real(0, 10, name="a4"),        # a4 must be positive and a4 <= a5
    ]

    # Define the objective function for minimization
    def objective(params):
        a1, a2, a3, a5, a4 = params  # Bayesian optimization orders variables alphabetically
        a4 = min(a4, a5)  # Ensure a4 <= a5

        _, score = model(data, train_idx, val_idx, a1, a2, a3, a4, a5)
        return -score  # Since `gp_minimize` minimizes the function, we negate accuracy

    # Run Bayesian Optimization
    result = gp_minimize(objective, search_space, n_calls=num_calls, random_state=None)

    # Extract best parameters
    best_a1, best_a2, best_a3, best_a5, best_a4 = result.x
    best_a4 = min(best_a4, best_a5)  # Ensure a4 ≤ a5
    best_accuracy = -result.fun

    best_params = [best_a1, best_a2, best_a3, best_a4, best_a5]

    return best_params, best_accuracy

# Example Usage:
best_params, best_validation_score = bayesian_optimization(predictclass, data, train_idx, val_idx)

# # # Extract the best values for a1, a2, a3, a4, a5
best_a1, best_a2, best_a3, best_a4, best_a5 = best_params

# # # Step 2: Test the Model Using the Best Parameters
y_pred_test, final_test_accuracy = predictclass(data, train_idx, test_idx, best_a1, best_a2, best_a3, best_a4, best_a5)

# # # Step 3: Print the Final Accuracy on the Test Set
print("\n🎯 Final Test Set Accuracy:", final_test_accuracy)
# Out:
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.11/dist-packages (0.10.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.4.2)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (25.1.0)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.6.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (24.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.5.0)
#
# 🎯 Final Test Set Accuracy: 0.618421052631579

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.nn as pyg_nn
from torch_geometric.utils import to_dense_adj
from sklearn.metrics import accuracy_score

class GraphAugmenter(nn.Module):
    def __init__(self, in_dim, hidden_dim):
        super(GraphAugmenter, self).__init__()
        self.gnn = pyg_nn.GCNConv(in_dim, hidden_dim)
        self.edge_mlp = nn.Sequential(
            nn.Linear(2 * hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, x, edge_index):
        node_emb = self.gnn(x, edge_index)
        row, col = edge_index
        edge_feat = torch.cat([node_emb[row], node_emb[col]], dim=-1)
        edge_weights = self.edge_mlp(edge_feat).squeeze()
        print("Edge Weights Shape:", edge_weights.shape)
        return edge_weights

class HeterophilicNodeClassifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, num_classes):
        super(HeterophilicNodeClassifier, self).__init__()

        self.augmenter = GraphAugmenter(in_dim, hidden_dim)
        self.gnn_high = pyg_nn.GCNConv(in_dim, hidden_dim)
        self.offset_mlp = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )
        self.final_mlp = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x, edge_index, train_indices, test_indices, initial_test_preds=None):
      print("\n🔄 Forward pass started")
      print(f"Total Nodes: {x.shape[0]}")
      print(f"Input Feature Shape: {x.shape}")
      print(f"Edge Index Shape: {edge_index.shape}")

      ### ✅ Input Checks ###
      assert isinstance(x, torch.Tensor), "❌ x must be a tensor!"
      assert x.dim() == 2, f"❌ x should have 2 dimensions (nodes, features), but got {x.shape}"
      assert not torch.isnan(x).any(), "❌ x contains NaN values!"
      assert not torch.isinf(x).any(), "❌ x contains Inf values!"

      assert isinstance(edge_index, torch.Tensor), "❌ edge_index must be a tensor!"
      assert edge_index.shape[0] == 2, f"❌ edge_index should have shape (2, num_edges), but got {edge_index.shape}"
      assert (edge_index >= 0).all(), "❌ edge_index contains negative values!"
      assert (edge_index < x.shape[0]).all(), "❌ edge_index contains out-of-bounds indices!"

      train_indices = torch.tensor(train_indices, dtype=torch.long, device=x.device)
      test_indices = torch.tensor(test_indices, dtype=torch.long, device=x.device)

      assert train_indices.dim() == 1, f"❌ train_indices should be 1D, got {train_indices.shape}"
      assert test_indices.dim() == 1, f"❌ test_indices should be 1D, got {test_indices.shape}"
      assert (train_indices < x.shape[0]).all(), "❌ train_indices contains out-of-bounds indices!"
      assert (test_indices < x.shape[0]).all(), "❌ test_indices contains out-of-bounds indices!"

      if initial_test_preds is not None:
          print("🚀 Initial predictions received, expanding...")
          assert isinstance(initial_test_preds, torch.Tensor), "❌ initial_test_preds must be a tensor!"
          assert initial_test_preds.dim() == 1, f"❌ initial_test_preds should be 1D, got {initial_test_preds.shape}"
          assert (initial_test_preds >= 0).all(), "❌ initial_test_preds contains negative values!"
          assert (initial_test_preds < self.final_mlp[-1].out_features).all(), "❌ initial_test_preds contains invalid class labels!"

      ### ✅ Graph Augmentation ###
      edge_weights = self.augmenter(x, edge_index)
      print("✔️ Edge weights computed")

      # High-pass GNN for heterophilic graphs
      h = self.gnn_high(x, edge_index, edge_weights)
      print(f"✔️ GNN high output shape: {h.shape}")

      # Offset term to escape local minima
      offset = self.offset_mlp(x)
      print(f"✔️ Offset shape: {offset.shape}")

      # Adaptive aggregation
      logits = self.final_mlp(h + offset)
      print(f"✔️ Logits shape: {logits.shape}")

      # Expand initial_test_preds to match full node size
      if initial_test_preds is not None:
          expanded_preds = torch.zeros_like(logits)

          print(f"Train Indices Shape: {train_indices.shape}")
          print(f"Test Indices Shape: {test_indices.shape}")
          print(f"Initial Test Predictions Shape: {initial_test_preds.shape}")

          # Ensure initial_test_preds is correctly shaped
          if initial_test_preds.shape[0] == len(test_indices):
              one_hot_preds = F.one_hot(initial_test_preds.long(), num_classes=logits.shape[1]).float()
          else:
              print(f"⚠️ Warning: initial_test_preds shape {initial_test_preds.shape} does not match test_indices length {len(test_indices)}")

              # Ensure only valid test indices are selected
              valid_test_mask = test_indices < initial_test_preds.shape[0]
              test_indices = test_indices[valid_test_mask]
              initial_test_preds = initial_test_preds[:len(test_indices)]

              print(f"✔️ Adjusted Test Indices Shape: {test_indices.shape}")
              print(f"✔️ Adjusted Initial Test Predictions Shape: {initial_test_preds.shape}")

              one_hot_preds = F.one_hot(initial_test_preds.long(), num_classes=logits.shape[1]).float()

          # ✅ Now we can safely assign one_hot_preds to expanded_preds
          if one_hot_preds.shape == expanded_preds[test_indices].shape:
              expanded_preds[test_indices] = one_hot_preds
          else:
              print(f"⚠️ Shape mismatch: Cannot assign {one_hot_preds.shape} to expanded_preds[test_indices] shape {expanded_preds[test_indices].shape}")


          print(f"✔️ Expanded predictions shape: {expanded_preds.shape}")
          logits = logits + 0.1 * (logits - expanded_preds)

      print("✅ Forward pass completed")
      return F.log_softmax(logits, dim=1)


# Training and Evaluation Code
def train_and_evaluate(model, data, train_indices, test_indices, initial_preds, epochs=1000, lr=0.01):
    criterion = nn.NLLLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()

        print(f"🔄 Epoch {epoch+1} training started")
        logits = model(data.x, data.edge_index, train_indices, test_indices, initial_preds)
        print("✔️ Logits computed")

        loss = criterion(logits[train_indices], data.y[train_indices])
        print(f"📉 Loss computed: {loss.item()}")

        loss.backward()
        optimizer.step()

        if epoch % 10 == 0:
            print(f"📌 Epoch {epoch+1}, Loss: {loss.item():.4f}")

    # Evaluation
    model.eval()
    with torch.no_grad():
        print("🔍 Evaluation started")
        logits = model(data.x, data.edge_index, train_indices, test_indices, initial_preds)
        predicted_classes = torch.argmax(logits, dim=1)
        test_predictions = predicted_classes[test_indices]

        final_accuracy = accuracy_score(data.y[test_indices].cpu().numpy(), test_predictions.cpu().numpy())

    print(f"\n🎯 Final Test Accuracy: {final_accuracy:.4f}")
    print("\n📊 Test Node Predictions:")
    for i, node in enumerate(test_indices):
        print(f"Node {node}: Predicted Class = {test_predictions[i].item()}, True Class = {data.y[node].item()}")

    return final_accuracy, test_predictions

# %%
# Compute initial test predictions
initial_preds, initial_accuracy = predictclass(data, train_idx, test_idx, best_a1, best_a2, best_a3, best_a4, best_a5)

# Ensure `initial_preds` is a tensor and on the correct device
initial_preds = torch.tensor(initial_preds, dtype=torch.long, device=data.x.device)

print(f"📊 Initial Classification Accuracy: {initial_accuracy:.4f}")

# Create the model
model = HeterophilicNodeClassifier(
    in_dim=data.x.shape[1],
    hidden_dim=32,
    num_classes=len(set(data.y.tolist()))
).to(data.x.device)  # Ensure model is on the correct device

# 🔄 Train the model before inference
final_accuracy, test_predictions = train_and_evaluate(
    model, data, train_idx, test_idx, initial_preds, epochs=100, lr=0.01
)

# ✅ Model evaluation after training
model.eval()
with torch.no_grad():
    logits = model(data.x, data.edge_index, train_idx, test_idx, initial_test_preds=initial_preds)
    predicted_classes = torch.argmax(logits, dim=1)

print(f"🎯 Final Classification Accuracy: {final_accuracy:.4f}")
# Out:
# <ipython-input-14-0b9ea04df471>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   initial_preds = torch.tensor(initial_preds, dtype=torch.long, device=data.x.device)
# 📊 Initial Classification Accuracy: 0.6184
# 🔄 Epoch 1 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.6483253240585327
# 📌 Epoch 1, Loss: 1.6483
# 🔄 Epoch 2 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.357092022895813
# 🔄 Epoch 3 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.0870391130447388
# 🔄 Epoch 4 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.7933756113052368
# 🔄 Epoch 5 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.526233434677124
# 🔄 Epoch 6 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.33007103204727173
# 🔄 Epoch 7 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.2264377623796463
# 🔄 Epoch 8 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.1530957967042923
# 🔄 Epoch 9 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.10507992655038834
# 🔄 Epoch 10 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.06792667508125305
# 🔄 Epoch 11 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.04512092098593712
# 📌 Epoch 11, Loss: 0.0451
# 🔄 Epoch 12 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.031067924574017525
# 🔄 Epoch 13 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.024465087801218033
# 🔄 Epoch 14 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.022784225642681122
# 🔄 Epoch 15 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.01820569671690464
# 🔄 Epoch 16 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.013913228176534176
# 🔄 Epoch 17 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.011643103323876858
# 🔄 Epoch 18 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.01022932305932045
# 🔄 Epoch 19 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.009110472165048122
# 🔄 Epoch 20 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.00815650075674057
# 🔄 Epoch 21 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0072658187709748745
# 📌 Epoch 21, Loss: 0.0073
# 🔄 Epoch 22 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0064491694793105125
# 🔄 Epoch 23 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.005670086480677128
# 🔄 Epoch 24 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.004917639773339033
# 🔄 Epoch 25 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.004200418014079332
# 🔄 Epoch 26 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.003529710927978158
# 🔄 Epoch 27 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0029169018380343914
# 🔄 Epoch 28 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.002380221616476774
# 🔄 Epoch 29 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0019220304675400257
# 🔄 Epoch 30 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0015325372805818915
# 🔄 Epoch 31 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0012096064165234566
# 📌 Epoch 31, Loss: 0.0012
# 🔄 Epoch 32 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0009479972068220377
# 🔄 Epoch 33 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0007403959752991796
# 🔄 Epoch 34 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0005788067355751991
# 🔄 Epoch 35 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0004551763995550573
# 🔄 Epoch 36 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.00036095239920541644
# 🔄 Epoch 37 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.00028952231514267623
# 🔄 Epoch 38 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.00023593533842358738
# 🔄 Epoch 39 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.00019702085410244763
# 🔄 Epoch 40 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.00016730935021769255
# 🔄 Epoch 41 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.00014380377251654863
# 📌 Epoch 41, Loss: 0.0001
# 🔄 Epoch 42 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.0001243518345290795
# 🔄 Epoch 43 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 0.00010758673306554556
# 🔄 Epoch 44 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 9.279102960135788e-05
# 🔄 Epoch 45 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 7.968544377945364e-05
# 🔄 Epoch 46 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.819616100983694e-05
# 🔄 Epoch 47 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 5.829818474012427e-05
# 🔄 Epoch 48 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 4.991529931430705e-05
# 🔄 Epoch 49 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 4.291961886337958e-05
# 🔄 Epoch 50 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 3.7141515349503607e-05
# 🔄 Epoch 51 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 3.239511715946719e-05
# 📌 Epoch 51, Loss: 0.0000
# 🔄 Epoch 52 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 2.850577948265709e-05
# 🔄 Epoch 53 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 2.5314100639661774e-05
# 🔄 Epoch 54 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 2.2702422938891686e-05
# 🔄 Epoch 55 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 2.0539249817375094e-05
# 🔄 Epoch 56 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.87388632184593e-05
# 🔄 Epoch 57 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.722914748825133e-05
# 🔄 Epoch 58 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.5953559341141954e-05
# 🔄 Epoch 59 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.4870174709358253e-05
# 🔄 Epoch 60 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.394290757161798e-05
# 🔄 Epoch 61 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.3147378922440112e-05
# 📌 Epoch 61, Loss: 0.0000
# 🔄 Epoch 62 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.2480689292715397e-05
# 🔄 Epoch 63 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.189597423945088e-05
# 🔄 Epoch 64 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.1382501725165639e-05
# 🔄 Epoch 65 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.0922703040705528e-05
# 🔄 Epoch 66 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.0517564078327268e-05
# 🔄 Epoch 67 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 1.0153416042157914e-05
# 🔄 Epoch 68 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 9.828314432525076e-06
# 🔄 Epoch 69 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 9.534447599435225e-06
# 🔄 Epoch 70 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 9.269864676753059e-06
# 🔄 Epoch 71 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 9.02870851859916e-06
# 📌 Epoch 71, Loss: 0.0000
# 🔄 Epoch 72 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 8.810005965642631e-06
# 🔄 Epoch 73 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 8.609849828644656e-06
# 🔄 Epoch 74 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ...
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 7.268251465575304e-06
# 🔄 Epoch 84 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 7.17548527973122e-06
# 🔄 Epoch 85 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 7.088579422998009e-06
# 🔄 Epoch 86 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 7.005578481766861e-06
# 🔄 Epoch 87 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.9264829107851256e-06
# 🔄 Epoch 88 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.851293164800154e-06
# 🔄 Epoch 89 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.7809860411216505e-06
# 🔄 Epoch 90 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.7106766437063925e-06
# 🔄 Epoch 91 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.644274435529951e-06
# 📌 Epoch 91, Loss: 0.0000
# 🔄 Epoch 92 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.579824002983514e-06
# 🔄 Epoch 93 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.519280759675894e-06
# 🔄 Epoch 94 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.45873569737887e-06
# 🔄 Epoch 95 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.4011214817583095e-06
# 🔄 Epoch 96 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.345459041767754e-06
# 🔄 Epoch 97 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.291749741649255e-06
# 🔄 Epoch 98 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.238039532036055e-06
# 🔄 Epoch 99 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.186282462294912e-06
# 🔄 Epoch 100 training started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# ✔️ Logits computed
# 📉 Loss computed: 6.135502644610824e-06
# 🔍 Evaluation started
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
#
# 🎯 Final Test Accuracy: 0.7368
#
# 📊 Test Node Predictions:
# Node 155: Predicted Class = 2, True Class = 2
# Node 6: Predicted Class = 1, True Class = 1
# Node 164: Predicted Class = 3, True Class = 2
# Node 60: Predicted Class = 1, True Class = 1
# Node 113: Predicted Class = 1, True Class = 1
# Node 182: Predicted Class = 2, True Class = 2
# Node 198: Predicted Class = 4, True Class = 4
# Node 248: Predicted Class = 2, True Class = 2
# Node 9: Predicted Class = 2, True Class = 0
# Node 118: Predicted Class = 4, True Class = 3
# Node 175: Predicted Class = 4, True Class = 3
# Node 217: Predicted Class = 1, True Class = 1
# Node 219: Predicted Class = 2, True Class = 3
# Node 139: Predicted Class = 2, True Class = 2
# Node 67: Predicted Class = 2, True Class = 0
# Node 225: Predicted Class = 4, True Class = 2
# Node 195: Predicted Class = 2, True Class = 2
# Node 15: Predicted Class = 2, True Class = 2
# Node 120: Predicted Class = 2, True Class = 2
# Node 24: Predicted Class = 1, True Class = 1
# Node 241: Predicted Class = 2, True Class = 2
# Node 19: Predicted Class = 2, True Class = 2
# Node 115: Predicted Class = 1, True Class = 1
# Node 68: Predicted Class = 2, True Class = 2
# Node 177: Predicted Class = 2, True Class = 2
# Node 45: Predicted Class = 2, True Class = 2
# Node 55: Predicted Class = 2, True Class = 2
# Node 10: Predicted Class = 2, True Class = 2
# Node 30: Predicted Class = 2, True Class = 2
# Node 234: Predicted Class = 2, True Class = 2
# Node 237: Predicted Class = 2, True Class = 2
# Node 33: Predicted Class = 2, True Class = 2
# Node 220: Predicted Class = 2, True Class = 2
# Node 196: Predicted Class = 2, True Class = 1
# Node 25: Predicted Class = 2, True Class = 3
# Node 126: Predicted Class = 3, True Class = 3
# Node 18: Predicted Class = 2, True Class = 3
# Node 73: Predicted Class = 2, True Class = 2
# Node 132: Predicted Class = 2, True Class = 2
# Node 82: Predicted Class = 1, True Class = 1
# Node 119: Predicted Class = 4, True Class = 4
# Node 97: Predicted Class = 1, True Class = 1
# Node 79: Predicted Class = 2, True Class = 4
# Node 84: Predicted Class = 1, True Class = 1
# Node 192: Predicted Class = 3, True Class = 3
# Node 16: Predicted Class = 2, True Class = 2
# Node 86: Predicted Class = 2, True Class = 2
# Node 124: Predicted Class = 2, True Class = 2
# Node 181: Predicted Class = 2, True Class = 1
# Node 38: Predicted Class = 1, True Class = 1
# Node 173: Predicted Class = 4, True Class = 3
# Node 158: Predicted Class = 1, True Class = 1
# Node 215: Predicted Class = 1, True Class = 1
# Node 101: Predicted Class = 2, True Class = 3
# Node 137: Predicted Class = 3, True Class = 3
# Node 66: Predicted Class = 2, True Class = 1
# Node 218: Predicted Class = 4, True Class = 3
# Node 185: Predicted Class = 2, True Class = 2
# Node 213: Predicted Class = 2, True Class = 2
# Node 204: Predicted Class = 1, True Class = 1
# Node 96: Predicted Class = 2, True Class = 2
# Node 226: Predicted Class = 2, True Class = 2
# Node 109: Predicted Class = 2, True Class = 2
# Node 150: Predicted Class = 1, True Class = 1
# Node 104: Predicted Class = 2, True Class = 2
# Node 212: Predicted Class = 2, True Class = 4
# Node 141: Predicted Class = 2, True Class = 2
# Node 159: Predicted Class = 4, True Class = 4
# Node 197: Predicted Class = 2, True Class = 3
# Node 69: Predicted Class = 2, True Class = 2
# Node 117: Predicted Class = 2, True Class = 2
# Node 75: Predicted Class = 4, True Class = 3
# Node 111: Predicted Class = 2, True Class = 2
# Node 235: Predicted Class = 2, True Class = 2
# Node 183: Predicted Class = 2, True Class = 0
# Node 238: Predicted Class = 2, True Class = 2
#
# 🔄 Forward pass started
# Total Nodes: 251
# Input Feature Shape: torch.Size([251, 1703])
# Edge Index Shape: torch.Size([2, 916])
# 🚀 Initial predictions received, expanding...
# Edge Weights Shape: torch.Size([916])
# ✔️ Edge weights computed
# ✔️ GNN high output shape: torch.Size([251, 32])
# ✔️ Offset shape: torch.Size([251, 32])
# ✔️ Logits shape: torch.Size([251, 5])
# Train Indices Shape: torch.Size([122])
# Test Indices Shape: torch.Size([76])
# Initial Test Predictions Shape: torch.Size([76])
# ✔️ Expanded predictions shape: torch.Size([251, 5])
# ✅ Forward pass completed
# 🎯 Final Classification Accuracy: 0.7368
